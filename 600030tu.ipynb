# %%
# -*- coding: utf-8 -*-

import matplotlib.pyplot as plt
from scipy.io import loadmat
import numpy as np
from sklearn.metrics import r2_score

def quota(real,pred,name):
    mape = np.mean(np.abs((pred - real) / real))
    # rmse
    rmse = np.sqrt(np.mean(np.square(pred - real)))
    # mae
    mae = np.mean(np.abs(pred - real))
    # R2
    r2 = r2_score(real, pred)
    print(name,'的mape:', mape, ' rmse:', rmse, ' mae:', mae, ' R2:', r2)


data01=loadmat('果实/600030LI-lstm_result.mat')['true']
data1=loadmat('果实/600030LI-lstm_result.mat')['pred']
data02=loadmat('果实/600030MS-lstm_result.mat')['true']
data2=loadmat('果实/600030MS-lstm_result.mat')['pred']
data03=loadmat('果实/600030lissa_lstm_result.mat')['true']
data3=loadmat('果实/600030lissa_lstm_result.mat')['pred']
data04=loadmat('果实/600030a2ssa_lstm_result.mat')['true']
data4=loadmat('果实/600030a2ssa_lstm_result.mat')['pred']

quota(data01,data1,'LSTM')
quota(data02,data2,'MS-LSTM')
quota(data03,data3,'SSA-LSTM')
quota(data04,data4,'MS-SSA-LSTM')
plt.rcParams['xtick.direction'] = 'in'
plt.rcParams['ytick.direction'] = 'in'
plt.figure()

plt.subplot(2,2,1)
plt.rcParams.update({'font.size':7})
plt.plot(data01,c='r', label='Actual Price')
plt.plot(data1,c='b',label='Predicted Price')
plt.title('LSTM',fontsize=8)
plt.ylabel('Price')
#plt.xlabel('Day')
plt.xlabel('Day', horizontalalignment='right', x=1.0)
plt.legend()

plt.subplot(2,2,2)
plt.plot(data02,c='r', label='Actual Price')
plt.plot(data2,c='b',label='Predicted Price')
plt.title('MS-LSTM',fontsize=8)
plt.ylabel('Price')
#plt.xlabel('Day')
plt.xlabel('Day', horizontalalignment='right', x=1.0)
plt.legend()

plt.subplot(2,2,3)
plt.plot(data03,c='r', label='Actual Price')
plt.plot(data3,c='b',label='Predicted Price')
plt.legend()
plt.title('SSA-LSTM',fontsize=8)
plt.ylabel('Price')
#plt.xlabel('Day')
plt.xlabel('Day', horizontalalignment='right', x=1.0)
# In[7] 画图
plt.subplot(2,2,4)
plt.plot(data04,c='r', label='Actual Price')
plt.plot(data4,c='b',label='Predicted Price')
plt.legend()
plt.title('MS-SSA-LSTM',fontsize=8)
plt.ylabel('Price')
#plt.xlabel('Day')
plt.xlabel('Day', horizontalalignment='right', x=1.0)

plt.subplots_adjust(left=None,bottom=None,right=None,top=None,wspace=0.25,hspace=0.4)
plt.savefig('合并图/600030.jpg',dpi=600)
plt.show()
# Out:
# LSTM 的mape: 0.03196202545468091  rmse: 0.9916463408362153  mae: 0.8101417008685402  R2: 0.9044926445971282
# MS-LSTM 的mape: 0.022524482833898605  rmse: 0.7210642658836912  mae: 0.5571748222829019  R2: 0.9495023533155244
# SSA-LSTM 的mape: 0.018782330476820715  rmse: 0.6084996558508062  mae: 0.4693359128269579  R2: 0.9652520567379763
# MS-SSA-LSTM 的mape: 0.01745324582163032  rmse: 0.5685856077845319  mae: 0.4382095664138092  R2: 0.9696610773429685
